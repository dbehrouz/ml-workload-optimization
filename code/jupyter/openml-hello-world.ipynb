# %%
from openml import datasets, tasks, runs, flows, setups, config
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns
import sys

config.apikey = '8e2079508005379adb9a60798696134e'
config.server = 'https://www.openml.org/api/v1'
config.set_cache_directory(os.path.expanduser('~/openml-cache'))

# %%
# select and filter flows made by scikit learn
flowsJson = flows.list_flows()
flowList = pd.DataFrame.from_dict(flowsJson, orient='index')

# %%
flowList.head()
# Out:
#                                      full_name external_version version  \
# 1     openml.evaluation.EuclideanDistance(1.0)             None       1
# 2      openml.evaluation.PolynomialKernel(1.0)             None       1
# 3             openml.evaluation.RBFKernel(1.0)             None       1
# 4  openml.evaluation.area_under_roc_curve(1.0)             None       1
# 5          openml.evaluation.average_cost(1.0)             None       1
#
#   uploader  id                                    name
# 1        1   1     openml.evaluation.EuclideanDistance
# 2        1   2      openml.evaluation.PolynomialKernel
# 3        1   3             openml.evaluation.RBFKernel
# 4        1   4  openml.evaluation.area_under_roc_curve
# 5        1   5          openml.evaluation.average_cost

# %%
data[:10][['did','name','NumberOfInstances','NumberOfFeatures']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-0b5ac0a9c4a1> in <module>()
# ----> 1 data[:10][['did','name','NumberOfInstances','NumberOfFeatures']]
#
# /usr/local/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    1956         if isinstance(key, (Series, np.ndarray, Index, list)):
#    1957             # either boolean or fancy integer index
# -> 1958             return self._getitem_array(key)
#    1959         elif isinstance(key, DataFrame):
#    1960             return self._getitem_frame(key)
#
# /usr/local/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_array(self, key)
#    2000             return self.take(indexer, axis=0, convert=False)
#    2001         else:
# -> 2002             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2003             return self.take(indexer, axis=1, convert=True)
# ...

# %%
# Out:
#                                      1       2         3       4      \
# MajorityClassSize                      684     684      1669      37
# MaxNominalAttDistinctValues             10       9         3       3
# MinorityClassSize                        0       0      1527      20
# NumberOfClasses                          6       6         2       2
# NumberOfFeatures                        39      39        37      17
# NumberOfInstances                      898     898      3196      57
# NumberOfInstancesWithMissingValues       0     898         0      56
# NumberOfMissingValues                    0   22175         0     326
# NumberOfNumericFeatures                  6       6         0       8
# NumberOfSymbolicFeatures                33      33        37       9
# did                                      1       2         3       4
# format                                ARFF    ARFF      ARFF    ARFF
# name                                anneal  anneal  kr-vs-kp   labor
# ...

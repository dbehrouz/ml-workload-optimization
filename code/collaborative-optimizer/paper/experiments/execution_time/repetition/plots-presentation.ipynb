# %% [markdown]
# ## Repetition Experiment
# In this notebook, we make the plots in Figure 4 (a)-(c) of Section 6.2
#
# Experiment result is located here:
#
# './experiment_results/remote/execution_time/repetition/kaggle_home_credit/cloud-41/2019-10-20/09-36.csv'

# %%
# numpy and pandas for data manipulation
import sys
# Suppress warnings
import warnings
import seaborn as sns
import matplotlib as plt
import networkx as nx
import numpy as np
import pandas as pd
import os
import matplotlib2tikz
plt.style.use('seaborn')
sns.set(style="whitegrid")
sns.set_style({'grid.color': '.5'})
plt.rc('hatch', color='white', linewidth=1)
plt.use('pgf')

FONT_SIZE = 25
plt.rcParams.update({
    "pgf.texsystem": "pdflatex",
    "text.usetex": True,   
    "font.family": "serif",
    "font.serif": [],
    "font.sans-serif": [],
    "font.monospace": [],
    "axes.labelsize": FONT_SIZE,     
    "font.size": FONT_SIZE,
    "legend.fontsize": FONT_SIZE, 
    "xtick.labelsize": FONT_SIZE,
    "ytick.labelsize": FONT_SIZE,
    #"figure.figsize": figsize(1.0), 
     "pgf.preamble": [
        r"\usepackage[utf8x]{inputenc}",    # use utf8 fonts becasue your computer can handle it :)
        r"\usepackage[T1]{fontenc}",        # plots will be generated using this preamble
        ]
})

warnings.filterwarnings('ignore')

# matplotlib and seaborn for plotting
import matplotlib.pyplot as plt
# %matplotlib inline
ROOT_RESULT_FOLDER = '/Users/bede01/Documents/work/phd-papers/ml-workload-optimization/experiment_results/remote'


SYSTEM_COLOR = sns.color_palette()[0]
BASELINE_COLOR = sns.color_palette()[1]

WRITE_DIRECTORY_ROOT = \
'/Users/bede01/Documents/work/phd-papers/ml-workload-optimization/slides/assets'

output_directory = WRITE_DIRECTORY_ROOT + '/experiment-results'
def create_folder(path):
    if not os.path.exists(os.path.dirname(path)):
        try:
            os.makedirs(os.path.dirname(path))
        except OSError as exc:  # Guard against race condition
            if exc.errno != errno.EEXIST:
                raise
WORKLOADS = {'start_here_a_gentle_introduction':'(a) Workload 1',
            'introduction_to_manual_feature_engineering':'(b) Workload 2',
            'introduction_to_manual_feature_engineering_p2': '(c) Workload 3'}

def savefig(filename):
    plt.savefig('{}.pgf'.format(filename), bbox_inches='tight')
    plt.savefig('{}.pdf'.format(filename), bbox_inches='tight')
# Out:
# /usr/local/lib/python2.7/site-packages/ipykernel_launcher.py:16: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "/usr/local/Cellar/python@2/2.7.16_1/Frameworks/Python.framework/Versions/2.7/lib/python2.7/runpy.py", line 174, in _run_module_as_main
#     "__main__", fname, loader, pkg_name)
#   File "/usr/local/Cellar/python@2/2.7.16_1/Frameworks/Python.framework/Versions/2.7/lib/python2.7/runpy.py", line 72, in _run_code
#     exec code in run_globals
#   File "/usr/local/lib/python2.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/usr/local/lib/python2.7/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/usr/local/lib/python2.7/site-packages/ipykernel/kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "/usr/local/lib/python2.7/site-packages/tornado/ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "/usr/local/lib/python2.7/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python2.7/site-packages/zmq/eventloop/zmqstream.py", line 450, in _handle_events
#     self._handle_recv()
#   File "/usr/local/lib/python2.7/site-packages/zmq/eventloop/zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/usr/local/lib/python2.7/site-packages/zmq/eventloop/zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)
#   File "/usr/local/lib/python2.7/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/usr/local/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/usr/local/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/usr/local/lib/python2.7/site-packages/ipykernel/ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/usr/local/lib/python2.7/site-packages/ipykernel/zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/usr/local/lib/python2.7/site-packages/IPython/core/interactiveshell.py", line 2718, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/usr/local/lib/python2.7/site-packages/IPython/core/interactiveshell.py", line 2822, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/usr/local/lib/python2.7/site-packages/IPython/core/interactiveshell.py", line 2882, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-3-be8049d01045>", line 5, in <module>
#     import seaborn as sns
#   File "/usr/local/lib/python2.7/site-packages/seaborn/__init__.py", line 6, in <module>
#     from .rcmod import *
#   File "/usr/local/lib/python2.7/site-packages/seaborn/rcmod.py", line 5, in <module>
#     from . import palettes, _orig_rc_params
#   File "/usr/local/lib/python2.7/site-packages/seaborn/palettes.py", line 12, in <module>
#     from .utils import desaturate, set_hls_values, get_color_cycle
#   File "/usr/local/lib/python2.7/site-packages/seaborn/utils.py", line 11, in <module>
#     import matplotlib.pyplot as plt
#   File "/usr/local/lib/python2.7/site-packages/matplotlib/pyplot.py", line 69, in <module>
#     from matplotlib.backends import pylab_setup
#   File "/usr/local/lib/python2.7/site-packages/matplotlib/backends/__init__.py", line 14, in <module>
#     line for line in traceback.format_stack()
#
#
#   app.launch_new_instance()

# %%
result_folder = ROOT_RESULT_FOLDER + '/execution_time/repetition/kaggle_home_credit'
FINAL_RESULT_FILE = result_folder + '/cloud-41/2019-10-20/09-36.csv'
result_file = result_folder + '/cloud-41/2020-02-05/22-43.csv'

# %%
CO = 'Collaborative'
KG = 'Naive'
HL = 'Helix'

HEADERS = [
    'timestamp', 'exp_id', 'repo', 'workload','type', 'rep', 'mat_rate',
    'run_time'
]
method_map = {'optimized':CO,'baseline':KG, 'helix':HL}
execution_times = pd.read_csv(result_file, header=None, names=HEADERS)
execution_times['type'] = execution_times['type'].replace(method_map)
execution_times['cumulative_run_time'] = execution_times.groupby(['exp_id','workload','type'])['run_time'].apply(lambda x: x.cumsum())

# %%
execution_times
# Out:
#    timestamp    exp_id                repo  \
# 0   01:09:48  DB3CB845  kaggle_home_credit
# 1   01:09:48  DB3CB845  kaggle_home_credit
# 2   01:16:43  12BE949F  kaggle_home_credit
# 3   01:16:43  12BE949F  kaggle_home_credit
# 4   01:28:37  947FFBA1  kaggle_home_credit
# 5   01:28:37  947FFBA1  kaggle_home_credit
# 6   01:41:17  B708BAD9  kaggle_home_credit
# 7   01:41:17  B708BAD9  kaggle_home_credit
# 8   02:01:31  C930BD24  kaggle_home_credit
# 9   02:01:31  C930BD24  kaggle_home_credit
# 10  02:08:01  4927DAC9  kaggle_home_credit
# 11  02:08:01  4927DAC9  kaggle_home_credit
# 12  02:19:49  C99F27DE  kaggle_home_credit
# 13  02:19:49  C99F27DE  kaggle_home_credit
# 14  02:26:44  5F42811B  kaggle_home_credit
# 15  02:26:44  5F42811B  kaggle_home_credit
# 16  02:38:41  5054E0CB  kaggle_home_credit
# 17  02:38:41  5054E0CB  kaggle_home_credit
# 18  02:51:28  72E86805  kaggle_home_credit
# 19  02:51:28  72E86805  kaggle_home_credit
# 20  03:11:58  6B208ECB  kaggle_home_credit
# 21  03:11:58  6B208ECB  kaggle_home_credit
# 22  03:18:31  3F4BD8A2  kaggle_home_credit
# 23  03:18:31  3F4BD8A2  kaggle_home_credit
# 24  03:30:23  C550695C  kaggle_home_credit
# 25  03:30:23  C550695C  kaggle_home_credit
# 26  03:37:18  0C6D6F20  kaggle_home_credit
# 27  03:37:18  0C6D6F20  kaggle_home_credit
# 28  03:49:13  413EB91A  kaggle_home_credit
# 29  03:49:13  413EB91A  kaggle_home_credit
# 30  04:01:49  BAB68973  kaggle_home_credit
# 31  04:01:49  BAB68973  kaggle_home_credit
# 32  04:21:47  F609C7FA  kaggle_home_credit
# 33  04:21:47  F609C7FA  kaggle_home_credit
# 34  04:28:22  F43CD518  kaggle_home_credit
# 35  04:28:22  F43CD518  kaggle_home_credit
# 36  06:34:03  0DF8E34D  kaggle_home_credit
# 37  06:34:03  0DF8E34D  kaggle_home_credit
# 38  06:38:16  231157EB  kaggle_home_credit
# 39  06:38:16  231157EB  kaggle_home_credit
# 40  06:47:11  27FCEB88  kaggle_home_credit
# 41  06:47:11  27FCEB88  kaggle_home_credit
# 42  06:51:43  4157D9D7  kaggle_home_credit
# 43  06:51:43  4157D9D7  kaggle_home_credit
# 44  06:55:55  0AB49720  kaggle_home_credit
# 45  06:55:55  0AB49720  kaggle_home_credit
# 46  07:04:36  36CD0008  kaggle_home_credit
# 47  07:04:36  36CD0008  kaggle_home_credit
# 48  07:09:05  406E23C2  kaggle_home_credit
# 49  07:09:05  406E23C2  kaggle_home_credit
# 50  07:13:18  9FE2F230  kaggle_home_credit
# 51  07:13:18  9FE2F230  kaggle_home_credit
# 52  07:22:22  153F6BF5  kaggle_home_credit
# 53  07:22:22  153F6BF5  kaggle_home_credit
#
#                                          workload           type  rep  \
# 0      introduction_to_manual_feature_engineering          Naive    1
# 1      introduction_to_manual_feature_engineering          Naive    2
# 2      introduction_to_manual_feature_engineering  Collaborative    1
# 3      introduction_to_manual_feature_engineering  Collaborative    2
# 4   introduction_to_manual_feature_engineering_p2          Naive    1
# 5   introduction_to_manual_feature_engineering_p2          Naive    2
# 6   introduction_to_manual_feature_engineering_p2  Collaborative    1
# 7   introduction_to_manual_feature_engineering_p2  Collaborative    2
# 8                start_here_a_gentle_introduction          Naive    1
# 9                start_here_a_gentle_introduction          Naive    2
# 10               start_here_a_gentle_introduction  Collaborative    1
# 11               start_here_a_gentle_introduction  Collaborative    2
# 12     introduction_to_manual_feature_engineering          Naive    1
# 13     introduction_to_manual_feature_engineering          Naive    2
# 14     introduction_to_manual_feature_engineering  Collaborative    1
# 15     introduction_to_manual_feature_engineering  Collaborative    2
# 16  introduction_to_manual_feature_engineering_p2          Naive    1
# 17  introduction_to_manual_feature_engineering_p2          Naive    2
# 18  introduction_to_manual_feature_engineering_p2  Collaborative    1
# 19  introduction_to_manual_feature_engineering_p2  Collaborative    2
# 20               start_here_a_gentle_introduction          Naive    1
# 21               start_here_a_gentle_introduction          Naive    2
# 22               start_here_a_gentle_introduction  Collaborative    1
# 23               start_here_a_gentle_introduction  Collaborative    2
# 24     introduction_to_manual_feature_engineering          Naive    1
# 25     introduction_to_manual_feature_engineering          Naive    2
# 26     introduction_to_manual_feature_engineering  Collaborative    1
# 27     introduction_to_manual_feature_engineering  Collaborative    2
# 28  introduction_to_manual_feature_engineering_p2          Naive    1
# 29  introduction_to_manual_feature_engineering_p2          Naive    2
# 30  introduction_to_manual_feature_engineering_p2  Collaborative    1
# 31  introduction_to_manual_feature_engineering_p2  Collaborative    2
# 32               start_here_a_gentle_introduction          Naive    1
# 33               start_here_a_gentle_introduction          Naive    2
# 34               start_here_a_gentle_introduction  Collaborative    1
# 35               start_here_a_gentle_introduction  Collaborative    2
# 36     introduction_to_manual_feature_engineering          Helix    1
# 37     introduction_to_manual_feature_engineering          Helix    2
# 38  introduction_to_manual_feature_engineering_p2          Helix    1
# 39  introduction_to_manual_feature_engineering_p2          Helix    2
# 40               start_here_a_gentle_introduction          Helix    1
# 41               start_here_a_gentle_introduction          Helix    2
# 42     introduction_to_manual_feature_engineering          Helix    1
# 43     introduction_to_manual_feature_engineering          Helix    2
# 44  introduction_to_manual_feature_engineering_p2          Helix    1
# 45  introduction_to_manual_feature_engineering_p2          Helix    2
# 46               start_here_a_gentle_introduction          Helix    1
# 47               start_here_a_gentle_introduction          Helix    2
# 48     introduction_to_manual_feature_engineering          Helix    1
# 49     introduction_to_manual_feature_engineering          Helix    2
# 50  introduction_to_manual_feature_engineering_p2          Helix    1
# 51  introduction_to_manual_feature_engineering_p2          Helix    2
# 52               start_here_a_gentle_introduction          Helix    1
# 53               start_here_a_gentle_introduction          Helix    2
#
#       mat_rate    run_time  cumulative_run_time
# 0          0.0  208.245746           208.245746
# 1          0.0  206.476753           414.722499
# 2   16777216.0  174.685267           174.685267
# 3   16777216.0   10.442684           185.127951
# 4          0.0  369.909023           369.909023
# 5          0.0  389.474996           759.384019
# 6   16777216.0  293.026737           293.026737
# 7   16777216.0   70.543435           363.570172
# 8          0.0  194.661522           194.661522
# 9          0.0  194.369958           389.031480
# 10  16777216.0  202.291987           202.291987
# 11  16777216.0   52.343035           254.635022
# 12         0.0  207.690615           207.690615
# 13         0.0  206.069639           413.760254
# 14  16777216.0  177.337175           177.337175
# 15  16777216.0    5.356907           182.694082
# 16         0.0  376.204034           376.204034
# 17         0.0  390.521895           766.725929
# 18  16777216.0  295.876795           295.876795
# 19  16777216.0   70.704520           366.581315
# 20         0.0  197.282977           197.282977
# 21         0.0  194.501038           391.784015
# 22  16777216.0  202.153490           202.153490
# 23  16777216.0   52.380505           254.533995
# 24         0.0  207.069619           207.069619
# 25         0.0  206.870433           413.940052
# 26  16777216.0  176.488248           176.488248
# 27  16777216.0    5.555972           182.044220
# 28         0.0  371.802048           371.802048
# 29         0.0  383.240458           755.042506
# 30  16777216.0  288.744572           288.744572
# 31  16777216.0   67.230375           355.974947
# 32         0.0  197.862509           197.862509
# 33         0.0  195.621959           393.484468
# 34  16777216.0  201.016140           201.016140
# 35  16777216.0   52.783247           253.799387
# 36  16777216.0  177.256123           177.256123
# 37  16777216.0    6.237248           183.493371
# 38  16777216.0  291.876694           291.876694
# 39  16777216.0  134.173084           426.049778
# 40  16777216.0  203.292990           203.292990
# 41  16777216.0   52.924760           256.217750
# 42  16777216.0  176.397980           176.397980
# 43  16777216.0    6.364852           182.762832
# 44  16777216.0  288.232653           288.232653
# 45  16777216.0  131.223802           419.456455
# 46  16777216.0  201.743210           201.743210
# 47  16777216.0   52.439675           254.182885
# 48  16777216.0  175.915788           175.915788
# 49  16777216.0    6.363411           182.279199
# 50  16777216.0  292.068143           292.068143
# 51  16777216.0  134.522205           426.590348
# 52  16777216.0  201.826697           201.826697
# 53  16777216.0   52.933692           254.760389

# %%
def plot_run_time(df, ax=None, workload_id=None):
    cat = sns.barplot(
        data=df,
        x='rep',
        y='run_time',
        ax=ax,
        hue='type',
        errwidth=3,
        errcolor='0',
        ci='sd',
        hue_order=[CO, HL, KG],
        palette={
            CO: SYSTEM_COLOR,
            KG: BASELINE_COLOR,
            HL: sns.color_palette()[2]
        })
    top = df['run_time'].max()
    cat.set_xlabel('\\textbf{{{}}}'.format(WORKLOADS[workload_id]), labelpad=5)
    cat.set_ylabel('Run Time (s)')
    if top < 250:
        cat.set_yticks(range(0, 201, 50))
        cat.set_ylim(0, 220)
    else:
        cat.set_yticks(range(0, 401, 100))
        cat.set_ylim(0, 420)
    cat.set_xticklabels(['Run 1', 'Run 2'])

    num_executions = len(df.rep.unique())
    for i, bar in enumerate(cat.patches):
        if i < num_executions:
            h = '/'
        elif i < 2*num_executions:
            h = 'O'
        else:
            h = 'X'
        bar.set_edgecolor('black')
        bar.set_hatch(h) 
    ax.tick_params(axis='y', which='major', pad=-2)
    ax.tick_params(axis='x', which='major', pad=-2)
    cat.get_legend().remove()

    return cat

# %%
plt.clf()
fig = plt.figure(figsize=(12,3.5))
ax1 = fig.add_subplot(131)
df = execution_times[execution_times['workload'] == 'start_here_a_gentle_introduction']
p1= plot_run_time(df,ax1,workload_id='start_here_a_gentle_introduction')

ax2 = fig.add_subplot(132)
df = execution_times[execution_times['workload'] == 'introduction_to_manual_feature_engineering']
p2=plot_run_time(df, ax2,workload_id='introduction_to_manual_feature_engineering')

ax3 = fig.add_subplot(133)
df = execution_times[execution_times['workload'] == 'introduction_to_manual_feature_engineering_p2']
p3=plot_run_time(df, ax3,workload_id='introduction_to_manual_feature_engineering_p2')
plt.tight_layout()

path = output_directory+'/repeated_workloads'
create_folder(path=path)
lg = fig.legend(
    borderpad=0.2,
    frameon=True,
    loc='upper center',
    handlelength=2,
    handletextpad=0.2,
    ncol=3,
    columnspacing=1,
    bbox_to_anchor=(0.5, 1.11))

fig.tight_layout(w_pad=0, h_pad=0)
lg.get_frame().set_edgecolor('black')
lg.get_frame().set_linewidth(2.0)

savefig(path)

# %%
df = execution_times[execution_times['workload'] == 'introduction_to_manual_feature_engineering']

# %%
df
# Out:
#    timestamp    exp_id                repo  \
# 0   01:09:48  DB3CB845  kaggle_home_credit
# 1   01:09:48  DB3CB845  kaggle_home_credit
# 2   01:16:43  12BE949F  kaggle_home_credit
# 3   01:16:43  12BE949F  kaggle_home_credit
# 12  02:19:49  C99F27DE  kaggle_home_credit
# 13  02:19:49  C99F27DE  kaggle_home_credit
# 14  02:26:44  5F42811B  kaggle_home_credit
# 15  02:26:44  5F42811B  kaggle_home_credit
# 24  03:30:23  C550695C  kaggle_home_credit
# 25  03:30:23  C550695C  kaggle_home_credit
# 26  03:37:18  0C6D6F20  kaggle_home_credit
# 27  03:37:18  0C6D6F20  kaggle_home_credit
# 36  06:34:03  0DF8E34D  kaggle_home_credit
# 37  06:34:03  0DF8E34D  kaggle_home_credit
# 42  06:51:43  4157D9D7  kaggle_home_credit
# 43  06:51:43  4157D9D7  kaggle_home_credit
# 48  07:09:05  406E23C2  kaggle_home_credit
# 49  07:09:05  406E23C2  kaggle_home_credit
#
#                                       workload type  rep    mat_rate  \
# 0   introduction_to_manual_feature_engineering   KG    1         0.0
# 1   introduction_to_manual_feature_engineering   KG    2         0.0
# 2   introduction_to_manual_feature_engineering   CO    1  16777216.0
# 3   introduction_to_manual_feature_engineering   CO    2  16777216.0
# 12  introduction_to_manual_feature_engineering   KG    1         0.0
# 13  introduction_to_manual_feature_engineering   KG    2         0.0
# 14  introduction_to_manual_feature_engineering   CO    1  16777216.0
# 15  introduction_to_manual_feature_engineering   CO    2  16777216.0
# 24  introduction_to_manual_feature_engineering   KG    1         0.0
# 25  introduction_to_manual_feature_engineering   KG    2         0.0
# 26  introduction_to_manual_feature_engineering   CO    1  16777216.0
# 27  introduction_to_manual_feature_engineering   CO    2  16777216.0
# 36  introduction_to_manual_feature_engineering   HL    1  16777216.0
# 37  introduction_to_manual_feature_engineering   HL    2  16777216.0
# 42  introduction_to_manual_feature_engineering   HL    1  16777216.0
# 43  introduction_to_manual_feature_engineering   HL    2  16777216.0
# 48  introduction_to_manual_feature_engineering   HL    1  16777216.0
# 49  introduction_to_manual_feature_engineering   HL    2  16777216.0
#
#       run_time  cumulative_run_time
# 0   208.245746           208.245746
# 1   206.476753           414.722499
# 2   174.685267           174.685267
# 3    10.442684           185.127951
# 12  207.690615           207.690615
# 13  206.069639           413.760254
# 14  177.337175           177.337175
# 15    5.356907           182.694082
# 24  207.069619           207.069619
# 25  206.870433           413.940052
# 26  176.488248           176.488248
# 27    5.555972           182.044220
# 36  177.256123           177.256123
# 37    6.237248           183.493371
# 42  176.397980           176.397980
# 43    6.364852           182.762832
# 48  175.915788           175.915788
# 49    6.363411           182.279199

# %%
text_df = df[(df.type!='KG') & (df.rep == 2)].groupby(['type','rep'])['run_time'].mean()

# %%
d['CO'][2]
# Out:
# 7.1185210000000003

# %%
def plot_run_one_by_one_time(df, loc=None, has_legend=False):
    cat = sns.catplot(
        data=df,
        x='rep',
        y='run_time',
        hue='type',
        kind='bar',
        errwidth=3,
        errcolor='0',
        ci='sd',
        hue_order=['CO', 'KG', 'HL'],
        palette={
            'CO': SYSTEM_COLOR,
            'KG': BASELINE_COLOR,
            'HL': sns.color_palette()[2]
        },
        legend=False)
    top = df['run_time'].max()
    cat.set_xlabels('Run', fontsize=AXIS_FONT)
    cat.set_ylabels('Run Time (s)', fontsize=AXIS_FONT)
    ax = cat.axes[0][0]
    plt.tick_params(labelsize=TICK_LABEL_SIZE)
    if top < 250:
        ax.set_yticks(range(0, 201, 50))
    else:
        ax.set_yticks(range(0, 401, 100))
    num_executions = len(df.rep.unique())
    for i, bar in enumerate(cat.ax.patches):
        if i < num_executions:
            h = '/'
        elif i < 2*num_executions:
            h = 'X'
        else:
            h = 'O'
        bar.set_edgecolor('black')
        bar.set_hatch(h)
    if has_legend:
        lg = plt.legend(
            loc='upper center',
            handlelength=2,
            handletextpad=0.1,
            fontsize=TICK_LABEL_SIZE,
            ncol=3,
            columnspacing=0.2,
            bbox_to_anchor=(0.55, 1.2))
    if loc is not None:
        cat.savefig(loc, bbox_inches='tight')

# %%
df = execution_times[execution_times['workload'] == 'start_here_a_gentle_introduction']
path = output_directory+'/start_here_a_gentle_introduction.pdf'
create_folder(path=path)
#plot_run_time(df, path)
plot_run_one_by_one_time(df, path)

# %%
df = execution_times[execution_times['workload'] == 'introduction_to_manual_feature_engineering']
path = output_directory+'/introduction_to_manual_feature_engineering.pdf'
create_folder(path=path)
#plot_run_time(df, path)
plot_run_one_by_one_time(df, path, has_legend=True)

# %%
df = execution_times[execution_times['workload'] == 'introduction_to_manual_feature_engineering_p2']
path = output_directory+'/introduction_to_manual_feature_engineering_p2.pdf'
create_folder(path=path)
#plot_run_time(df, path)
plot_run_one_by_one_time(df,path)

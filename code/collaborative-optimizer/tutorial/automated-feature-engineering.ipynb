# %% [markdown]
# # Automated Feature Engineering in Python
# This notebook is based on the tutorial: https://towardsdatascience.com/automated-feature-engineering-in-python-99baf11cc219

# %%
# pandas and numpy for data manipulation
import pandas as pd
import numpy as np

# featuretools for automated feature engineering
import featuretools as ft

# ignore warnings from pandas
import warnings
warnings.filterwarnings('ignore')

# %%
# Read in the data
clients = pd.read_csv('data/clients.csv', parse_dates = ['joined'])
loans = pd.read_csv('data/loans.csv', parse_dates = ['loan_start', 'loan_end'])
payments = pd.read_csv('data/payments.csv', parse_dates = ['payment_date'])

# %%
# Group loans by client id and calculate mean, max, min of loans
stats = loans.groupby('client_id')['loan_amount'].agg(['mean', 'max', 'min'])
stats.columns = ['mean_loan_amount', 'max_loan_amount', 'min_loan_amount']

# Merge with the clients dataframe
stats = clients.merge(stats, left_on = 'client_id', right_index=True, how = 'left')

stats.head(10)
# Out:
#    client_id     joined  income  credit_score  mean_loan_amount  \
# 0      46109 2002-04-16  172677           527       8951.600000
# 1      49545 2007-11-14  104564           770      10289.300000
# 2      41480 2013-03-11  122607           585       7894.850000
# 3      46180 2001-11-06   43851           562       7700.850000
# 4      25707 2006-10-06  211422           621       7963.950000
# 5      39505 2011-10-14  153873           610       7424.050000
# 6      32726 2006-05-01  235705           730       6633.263158
# 7      35089 2010-03-01  131176           771       6939.200000
# 8      35214 2003-08-08   95849           696       7173.555556
# 9      48177 2008-06-09  190632           769       7424.368421
#
#    max_loan_amount  min_loan_amount
# 0            14049              559
# 1            14971             3851
# 2            14399              811
# 3            14081             1607
# 4            13913             1212
# 5            14575              904
# 6            14802              851
# 7            13194              773
# 8            14767              667
# 9            14740              659

# %%
# Create a month column
clients['join_month'] = clients['joined'].dt.month

# Create a log of income column
clients['log_income'] = np.log(clients['income'])

clients.head()
# Out:
#    client_id     joined  income  credit_score  join_month  log_income
# 0      46109 2002-04-16  172677           527           4   12.059178
# 1      49545 2007-11-14  104564           770          11   11.557555
# 2      41480 2013-03-11  122607           585           3   11.716739
# 3      46180 2001-11-06   43851           562          11   10.688553
# 4      25707 2006-10-06  211422           621          10   12.261611

# %%
# Groupby client id and calculate mean, max, min previous loan size
stats = loans.groupby('client_id')['loan_amount'].agg(['mean', 'max', 'min'])
stats.columns = ['mean_loan_amount', 'max_loan_amount', 'min_loan_amount']
stats.head()
# Out:
#            mean_loan_amount  max_loan_amount  min_loan_amount
# client_id
# 25707           7963.950000            13913             1212
# 26326           7270.062500            13464             1164
# 26695           7824.722222            14865             2389
# 26945           7125.933333            14593              653
# 29841           9813.000000            14837             2778

# %%
# Merge with the clients dataframe
clients.merge(stats, left_on = 'client_id', right_index=True, how = 'left').head(10)
# Out:
#    client_id     joined  income  credit_score  join_month  log_income  \
# 0      46109 2002-04-16  172677           527           4   12.059178
# 1      49545 2007-11-14  104564           770          11   11.557555
# 2      41480 2013-03-11  122607           585           3   11.716739
# 3      46180 2001-11-06   43851           562          11   10.688553
# 4      25707 2006-10-06  211422           621          10   12.261611
# 5      39505 2011-10-14  153873           610          10   11.943883
# 6      32726 2006-05-01  235705           730           5   12.370336
# 7      35089 2010-03-01  131176           771           3   11.784295
# 8      35214 2003-08-08   95849           696           8   11.470529
# 9      48177 2008-06-09  190632           769           6   12.158100
#
#    mean_loan_amount  max_loan_amount  min_loan_amount
# 0       8951.600000            14049              559
# 1      10289.300000            14971             3851
# 2       7894.850000            14399              811
# 3       7700.850000            14081             1607
# 4       7963.950000            13913             1212
# 5       7424.050000            14575              904
# 6       6633.263158            14802              851
# 7       6939.200000            13194              773
# 8       7173.555556            14767              667
# 9       7424.368421            14740              659

# %%
es = ft.EntitySet(id = 'clients')

# %%
# Create an entity from the client dataframe
# This dataframe already has an index and a time index
es = es.entity_from_dataframe(entity_id = 'clients', dataframe = clients, 
                              index = 'client_id', time_index = 'joined')

# %%
# Create an entity from the loans dataframe
# This dataframe already has an index and a time index
es = es.entity_from_dataframe(entity_id = 'loans', dataframe = loans, 
                              variable_types = {'repaid': ft.variable_types.Categorical},
                              index = 'loan_id', 
                              time_index = 'loan_start')

# %%
# Create an entity from the payments dataframe
# This does not yet have a unique index
es = es.entity_from_dataframe(entity_id = 'payments', 
                              dataframe = payments,
                              variable_types = {'missed': ft.variable_types.Categorical},
                              make_index = True,
                              index = 'payment_id',
                              time_index = 'payment_date')

# %%
es
# Out:
# Entityset: clients
#   Entities:
#     clients [Rows: 25, Columns: 6]
#     loans [Rows: 443, Columns: 8]
#     payments [Rows: 3456, Columns: 5]
#   Relationships:
#     No relationships

# %%
# Relationship between clients and previous loans
r_client_previous = ft.Relationship(es['clients']['client_id'],
                                    es['loans']['client_id'])

# Add the relationship to the entity set
es = es.add_relationship(r_client_previous)

# %%
# Relationship between previous loans and previous payments
r_payments = ft.Relationship(es['loans']['loan_id'],
                                      es['payments']['loan_id'])

# Add the relationship to the entity set
es = es.add_relationship(r_payments)

es
# Out:
# Entityset: clients
#   Entities:
#     clients [Rows: 25, Columns: 6]
#     loans [Rows: 443, Columns: 8]
#     payments [Rows: 3456, Columns: 5]
#   Relationships:
#     loans.client_id -> clients.client_id
#     payments.loan_id -> loans.loan_id

# %%
primitives = ft.list_primitives()
pd.options.display.max_colwidth = 100
primitives[primitives['type'] == 'aggregation']
# Out:
#                 name         type  \
# 0                std  aggregation
# 1              count  aggregation
# 2                all  aggregation
# 3               last  aggregation
# 4      n_most_common  aggregation
# 5                min  aggregation
# 6              trend  aggregation
# 7                max  aggregation
# 8                sum  aggregation
# 9             median  aggregation
# 10        num_unique  aggregation
# 11  avg_time_between  aggregation
# 12              mode  aggregation
# 13          num_true  aggregation
# 14   time_since_last  aggregation
# 15              skew  aggregation
# 16               any  aggregation
# 17      percent_true  aggregation
# 18              mean  aggregation
#
#                                          description
# 0   Computes the average value of a numeric feature.
# 1   Computes the average value of a numeric feature.
# 2   Computes the average value of a numeric feature.
# 3   Computes the average value of a numeric feature.
# 4   Computes the average value of a numeric feature.
# 5   Computes the average value of a numeric feature.
# 6   Computes the average value of a numeric feature.
# 7   Computes the average value of a numeric feature.
# 8   Computes the average value of a numeric feature.
# 9   Computes the average value of a numeric feature.
# 10  Computes the average value of a numeric feature.
# 11  Computes the average value of a numeric feature.
# 12  Computes the average value of a numeric feature.
# 13  Computes the average value of a numeric feature.
# 14  Computes the average value of a numeric feature.
# 15  Computes the average value of a numeric feature.
# 16  Computes the average value of a numeric feature.
# 17  Computes the average value of a numeric feature.
# 18  Computes the average value of a numeric feature.

# %%
primitives[primitives['type'] == 'transform']
# Out:
#                                name       type description
# 19                              and  transform
# 20     greater_than_equal_to_scalar  transform
# 21                   modulo_numeric  transform
# 22            greater_than_equal_to  transform
# 23                          is_null  transform
# 24                divide_by_feature  transform
# 25                           second  transform
# 26        less_than_equal_to_scalar  transform
# 27               add_numeric_scalar  transform
# 28                             year  transform
# 29                           negate  transform
# 30                             diff  transform
# 31                        haversine  transform
# 32                        less_than  transform
# 33              time_since_previous  transform
# 34               less_than_equal_to  transform
# 35                       days_since  transform
# 36                      add_numeric  transform
# 37            modulo_numeric_scalar  transform
# 38                       is_weekend  transform
# 39              greater_than_scalar  transform
# 40  scalar_subtract_numeric_feature  transform
# 41                         latitude  transform
# 42                         absolute  transform
# 43            divide_numeric_scalar  transform
# 44                             week  transform
# 45                   divide_numeric  transform
# 46                 not_equal_scalar  transform
# 47          subtract_numeric_scalar  transform
# 48                 multiply_numeric  transform
# 49                     equal_scalar  transform
# 50                       characters  transform
# 51                              not  transform
# 52                            month  transform
# 53                              day  transform
# 54                           minute  transform
# 55                        not_equal  transform
# 56                modulo_by_feature  transform
# 57                             hour  transform
# 58                 less_than_scalar  transform
# 59                         numwords  transform
# 60                 subtract_numeric  transform
# 61                            equal  transform
# 62                        longitude  transform
# 63          multiply_numeric_scalar  transform
# 64                       percentile  transform
# 65                          weekday  transform
# 66                       time_since  transform
# 67                     greater_than  transform
# 68                             isin  transform
# 69                               or  transform

# %%
# Create new features using specified primitives
features, feature_names = ft.dfs(entityset = es, target_entity = 'clients', 
                                 agg_primitives = ['mean', 'max', 'percent_true', 'last'],
                                 trans_primitives = ['year', 'month', 'subtract_numeric', 'divide_numeric'])

# %%
pd.DataFrame(features['MONTH(joined)'].head())
# Out:
#            MONTH(joined)
# client_id
# 25707                 10
# 26326                  5
# 26695                  8
# 26945                 11
# 29841                  8

# %%
pd.DataFrame(features['MEAN(payments.payment_amount)'].head())
# Out:
#            MEAN(payments.payment_amount)
# client_id
# 25707                        1178.552795
# 26326                        1166.736842
# 26695                        1207.433824
# 26945                        1109.473214
# 29841                        1439.433333

# %%
features.head()
# Out:
#            credit_score  income  log_income  join_month  \
# client_id
# 25707               621  211422   12.261611          10
# 26326               633  227920   12.336750           5
# 26695               680  174532   12.069863           8
# 26945               806  214516   12.276140          11
# 29841               523   38354   10.554614           8
#
#            credit_score / income  MEAN(loans.loan_amount)  LAST(loans.rate)  \
# client_id
# 25707                          0              7963.950000              7.40
# 26326                          0              7270.062500              1.45
# 26695                          0              7824.722222              0.90
# 26945                          0              7125.933333              2.86
# 29841                          0              9813.000000              5.09
#
#            income / join_month  LAST(loans.loan_amount)  \
# client_id
# 25707                    21142                     2203
# 26326                    45584                     5275
# 26695                    21816                    13918
# 26945                    19501                     9249
# 29841                     4794                     7223
#
#            MAX(loans.loan_amount)  \
# client_id
# 25707                       13913
# 26326                       13464
# 26695                       14865
# 26945                       14593
# 29841                       14837
#
#                                   ...                           \
# client_id                         ...
# 25707                             ...
# 26326                             ...
# 26695                             ...
# 26945                             ...
# 29841                             ...
#
#            income - LAST(loans.rate)  \
# client_id
# 25707                      211414.60
# 26326                      227918.55
# 26695                      174531.10
# 26945                      214513.14
# 29841                       38348.91
#
#            join_month - log_income / MEAN(loans.rate)  \
# client_id
# 25707                                       -0.650449
# 26326                                       -2.914300
# 26695                                       -1.650316
# 26945                                       -0.446932
# 29841                                       -0.741543
#
#            LAST(loans.rate) - log_income  \
# client_id
# 25707                          -4.861611
# 26326                         -10.886750
# 26695                         -11.169863
# 26945                          -9.416140
# 29841                          -5.464614
#
#            MEAN(loans.rate) / credit_score - income  \
# client_id
# 25707                                     -0.000016
# 26326                                     -0.000011
# 26695                                     -0.000014
# 26945                                     -0.000013
# 29841                                     -0.000091
#
#            MAX(loans.rate) / income - log_income  \
# client_id
# 25707                                   0.000045
# 26326                                   0.000030
# 26695                                   0.000037
# 26945                                   0.000026
# 29841                                   0.000176
#
#            credit_score - join_month / credit_score - income  \
# client_id
# 25707                                                     -1
# 26326                                                     -1
# 26695                                                     -1
# 26945                                                     -1
# 29841                                                     -1
#
#            MEAN(loans.loan_amount) / MAX(loans.rate)  \
# client_id
# 25707                                     843.638771
# 26326                                    1080.247028
# 26695                                    1201.954258
# 26945                                    1261.227139
# 29841                                    1451.627219
#
#            log_income - MEAN(payments.payment_amount)  \
# client_id
# 25707                                    -1166.291184
# 26326                                    -1154.400092
# 26695                                    -1195.363960
# 26945                                    -1097.197075
# 29841                                    -1428.878719
#
#            credit_score - log_income / income  \
# client_id
# 25707                                0.002879
# 26326                                0.002723
# 26695                                0.003827
# 26945                                0.003700
# 29841                                0.013361
#
#            credit_score - join_month / LAST(loans.loan_amount)
# client_id
# 25707                                                        0
# 26326                                                        0
# 26695                                                        0
# 26945                                                        0
# 29841                                                        0
#
# [5 rows x 464 columns]

# %%
# Show a feature with a depth of 2
pd.DataFrame(features['LAST(loans.MEAN(payments.payment_amount))'].head(10))
# Out:
#            LAST(loans.MEAN(payments.payment_amount))
# client_id
# 25707                                     293.500000
# 26326                                     977.375000
# 26695                                    1769.166667
# 26945                                    1598.666667
# 29841                                    1125.500000
# 32726                                     799.500000
# 32885                                    1729.000000
# 32961                                     282.600000
# 35089                                     110.400000
# 35214                                    1410.250000

# %%
# Perform deep feature synthesis without specifying primitives
features, feature_names = ft.dfs(entityset=es, target_entity='clients', 
                                 max_depth = 2)

# %%
features.iloc[:, 4:].head()
# Out:
#            MEAN(loans.loan_amount)  NUM_UNIQUE(loans.repaid)  \
# client_id
# 25707                  7963.950000                         2
# 26326                  7270.062500                         2
# 26695                  7824.722222                         2
# 26945                  7125.933333                         2
# 29841                  9813.000000                         2
#
#            NUM_UNIQUE(loans.loan_type)  COUNT(loans)  STD(loans.rate)  \
# client_id
# 25707                                4            20         2.484186
# 26326                                4            16         2.057142
# 26695                                4            18         1.561659
# 26945                                4            15         1.619717
# 29841                                4            18         2.122904
#
#            MODE(payments.missed)  MEAN(payments.payment_amount)  \
# client_id
# 25707                          1                    1178.552795
# 26326                          1                    1166.736842
# 26695                          0                    1207.433824
# 26945                          1                    1109.473214
# 29841                          1                    1439.433333
#
#            MAX(loans.loan_amount)  MAX(payments.payment_amount)  \
# client_id
# 25707                       13913                          2704
# 26326                       13464                          2658
# 26695                       14865                          2932
# 26945                       14593                          2768
# 29841                       14837                          2898
#
#            COUNT(payments)                    ...                     \
# client_id                                     ...
# 25707                  161                    ...
# 26326                  133                    ...
# 26695                  136                    ...
# 26945                  112                    ...
# 29841                  150                    ...
#
#            MEAN(loans.MIN(payments.payment_amount))  \
# client_id
# 25707                                    815.050000
# 26326                                    829.500000
# 26695                                    944.888889
# 26945                                    820.866667
# 29841                                   1002.166667
#
#            SKEW(loans.NUM_UNIQUE(payments.missed))  \
# client_id
# 25707                                          0.0
# 26326                                          0.0
# 26695                                          0.0
# 26945                                          0.0
# 29841                                          0.0
#
#            STD(loans.NUM_UNIQUE(payments.missed))  \
# client_id
# 25707                                         0.0
# 26326                                         0.0
# 26695                                         0.0
# 26945                                         0.0
# 29841                                         0.0
#
#            MODE(loans.YEAR(loan_start))  MIN(loans.COUNT(payments))  \
# client_id
# 25707                              2010                           5
# 26326                              2003                           5
# 26695                              2003                           5
# 26945                              2002                           5
# 29841                              2005                           6
#
#            SKEW(loans.MIN(payments.payment_amount))  \
# client_id
# 25707                                      0.190578
# 26326                                      0.350923
# 26695                                      0.695612
# 26945                                      0.203092
# 29841                                      0.098515
#
#            MAX(loans.SUM(payments.payment_amount))  \
# client_id
# 25707                                        19246
# 26326                                        19295
# 26695                                        22686
# 26945                                        20181
# 29841                                        21454
#
#            SUM(loans.NUM_UNIQUE(payments.missed))  \
# client_id
# 25707                                          40
# 26326                                          32
# 26695                                          36
# 26945                                          30
# 29841                                          36
#
#            MEAN(loans.MEAN(payments.payment_amount))  \
# client_id
# 25707                                    1175.760996
# 26326                                    1161.691608
# 26695                                    1221.200615
# 26945                                    1115.150112
# 29841                                    1455.233737
#
#            MEAN(loans.MAX(payments.payment_amount))
# client_id
# 25707                                   1578.750000
# 26326                                   1547.500000
# 26695                                   1518.833333
# 26945                                   1411.600000
# 29841                                   1866.000000
#
# [5 rows x 90 columns]
